# %%
! pip install OpenAI

# %%
# !pip install c
# !pip install Cohere
# !pip install langchin_community
# !pip install -U langchain langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 37.6 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...
# ERROR: Could not find a version that satisfies the requirement langchin_community (from versions: none)
# ERROR: No matching distribution found for langchin_community
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 44.7 MB/s eta 0:00:00
# ...

# %%
# !pip install -U langchain-cohere
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from langchain_cohere import ChatCohere
from langchain_core.messages import HumanMessage

llm = ChatCohere(
    model="command-a-03-2025"
)

prompt = """
Result sould be in bullet points with emioji , you are a homeopathy expert .
'what is the best piles medicine'
"""
result = llm.invoke(prompt)
print(result.content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_302/3860250552.py in <cell line: 0>()
# ----> 1 from langchain_cohere import ChatCohere
#       2 from langchain_core.messages import HumanMessage
#       3
#       4 llm = ChatCohere(
#       5     model="command-a-03-2025"
#
# ModuleNotFoundError: No module named 'langchain_cohere'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install -q langchain langchain-openai openai

# %%
from langchain_openai import OpenAI
import os
os.environ["OpenAI_API_key"]=

# %%
# !pip install OpenAI
# !pip install langchain
# !pip install Cohere
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 29.7 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 364.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# ...

# %%
import os
from google.colab import userdata
os.environ["OPENAI_API_KEY"]=  userdata.get("OpenAI_API_key")
#os.environ["Cohere_API_key"]

# %%
from langchain_openai import OpenAI
llm = OpenAI(temperature=0, max_tokens= 256)

result = llm.invoke("benefit of homeopathy in 4 lines  ")

# %%
print(result)
# Out:
# 1. Natural and gentle: Homeopathy uses natural substances in highly diluted forms, making it a gentle and non-invasive form of treatment.
#
# 2. Individualized approach: Homeopathy treats each person as a unique individual, taking into account their physical, mental, and emotional symptoms to find the most suitable remedy.
#
# 3. Safe and non-toxic: Homeopathic remedies are made from natural substances and are non-toxic, making them safe for people of all ages, including infants and pregnant women.
#
# 4. Holistic healing: Homeopathy aims to treat the root cause of the illness rather than just the symptoms, promoting overall health and well-being.

# %%
result = llm.invoke("""
what is the sentiment of this review.Give me only positive and negative as answer
{input}

input = " i have very good helth and prosperity and aboundance"

""")
print(result)
# Out:
# Positive

# %% [markdown]
#                   **Prompt engineering **

# %%
import pandas as pd

# create a list of log meassge
log_message =[
    "INFO: Serever started successfully",
    "Warning: lOW disk Space ",
    "Critical: Database connection failed",
    "Info: new feature released",
]
